# %% [markdown]
# Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Specify the correct date format
date_format = '%d/%m/%Y %H:%M'

# %% [markdown]
# Uploading Csv files & Filtering for Huobi & OKX Launch on 8.5.21

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\Huobi_SHIBA_8-11.5.21_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\OKX_SHIBA_8-11.5.21_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\Binance_SHIB_10-14.5.21_5min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\KuCoin_SHIBA_10-14.5.21_5min.csv')
df5 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\CoinBase_SHIBA_16-19.9.21_5min.csv')
df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)
df5['timestamp'] = pd.to_datetime(df5['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2021-05-09 08:00'
end_time = '2021-05-09 16:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]
filtered_df5 = df5[(df5['timestamp'] >= start_time) & (df5['timestamp'] <= end_time)]

# %% [markdown]
# Uploading Csv files & Filtering for Binance and KuCoin Launch on 10.5.21

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\Huobi_SHIBA_8-11.5.21_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\OKX_SHIBA_8-11.5.21_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\Binance_SHIB_10-14.5.21_5min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\KuCoin_SHIBA_10-14.5.21_5min.csv')
df5 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\CoinBase_SHIBA_16-19.9.21_5min.csv')
df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)
df5['timestamp'] = pd.to_datetime(df5['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2021-05-10 02:30'
end_time = '2021-05-10 10:30'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]
filtered_df5 = df5[(df5['timestamp'] >= start_time) & (df5['timestamp'] <= end_time)]

# %% [markdown]
# Uploading Csv files & Filtering for CoinBase Launch on 16.9.21

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\Huobi_SHIBA_16-18.9.21_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\OKX_SHIBA_16-18.9.21_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\Binance_Shiba_16.9.21_5min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\KuCoin_SHIBA_16-20.9.21_5min.csv')
df5 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\CoinBase_SHIBA_16-19.9.21_5min.csv')
df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)
df5['timestamp'] = pd.to_datetime(df5['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2021-09-16 16:00'
end_time = '2021-09-17 00:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]
filtered_df5 = df5[(df5['timestamp'] >= start_time) & (df5['timestamp'] <= end_time)]

# %% [markdown]
# Shiba Launch on Huobi plot

# %%
# Plot filtered data
plt.figure(figsize=(15, 9))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))
plt.xlabel('Time ',fontsize=15)
plt.ylabel('Price $',fontsize=15)
plt.title('Shiba Launch on Huobi  8.5.21',fontsize=30)
plt.xticks(rotation=45,fontsize=15)
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Shiba Launch on OKX plot

# %%
# Plot filtered data
plt.figure(figsize=(15, 9))
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))
plt.xlabel('Time ',fontsize=15)
plt.ylabel('Price $',fontsize=15)
plt.title('Shiba Launch on OKX  8.5.21',fontsize=30)
plt.xticks(rotation=45,fontsize=15)
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Shiba Launch on OKX & Huobi 8.5.21, Combined

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))
plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('Shiba Launch on Huobi & OKX ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Binance', color='red')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))
plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('Shiba Launch on Binance, Lined with Huobi & OKX ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='KuCoin', color='purple')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))
plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('Shiba Launch on KuCoin, Lined with  Huobi & OKX ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Binance', color='red')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='KuCoin', color='purple')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))
plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('Shiba Launch on Binance & KuCoin, Lined with Huobi & OKX ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Binance', color='red')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='KuCoin', color='purple')
plt.plot(filtered_df5['timestamp'], filtered_df5['open'], label='CoinBase', color='orange')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))
plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('Shiba Launch on CoinBase 16.9.21', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()
