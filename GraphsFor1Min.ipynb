# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Specify the correct date format
date_format = '%d/%m/%Y %H:%M'

# %% [markdown]
# 1.5.23, PEPE okx launch

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\1- 1.5.23\Houbi_PEPE_1.5.23_1min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\1- 1.5.23\OKX_PEPE_1.5.23_1min.csv')
#df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\3-5.5.23\Houbi_PEPE_6.5.23_1min.csv')
#df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\6\Binance_PEPE_6.5.23_1min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
#df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
#df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2023-05-01 09:00'
end_time = '2023-05-01 09:30'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
#filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
#filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')

# Formatting
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=2))
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.FormatStrFormatter('%.8f'))  # For precise y-axis values
plt.xlabel('Time', fontsize=20)
plt.ylabel(' Price $', fontsize=20)
plt.title('PEPE 1.5.21 , 1 min interval ', fontsize=25)
plt.xticks(rotation=45, fontsize=20)  # Font size for X-axis ticks
plt.yticks(fontsize=20)  # Font size for Y-axis ticks
plt.legend(fontsize=20)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# 5.5.23, PEPE BEFORE KuCoin's Launch

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\3-5.5.23\Huobi_PEPE_5.5.23_1min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\3-5.5.23\OKX_PEPE_5.5.23_1min.csv')
#df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\3-5.5.23\Houbi_PEPE_6.5.23_1min.csv')
#df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\6\Binance_PEPE_6.5.23_1min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
#df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
#df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2023-05-05 11:40'
end_time = '2023-05-05 12:20'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
#filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
#filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
#plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='KuCoin', color='purple')
#plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='Binance', color='red')

plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=2))
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.FormatStrFormatter('%.8f'))  # For precise y-axis values

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('Pepe, 5.5.23 , Before KuCoin Launch', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# 5.5.23 , PEPE, KuCoin launch

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\5-5.5.23\KuCoin_PEPE_5.5.23_1min2.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\5-5.5.23\OKX_PEPE_5.5.23_1min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\5-5.5.23\Houbi_PEPE_5.5.23_1min.csv')
#df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\6\Binance_PEPE_6.5.23_1min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
#df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2023-05-05 14:00'
end_time = '2023-05-05 15:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
#filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='KuCoin', color='purple')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='blue')
#plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='Binance', color='red')

plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=2))
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.FormatStrFormatter('%.8f'))  # For precise y-axis values

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('Pepe, 5.5.23 , KuCoin Launch, lined with okx&Huobi ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\6-6.5.23\KuCoin_PEPE_6.5.23_1min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\6-6.5.23\OKX_PEPE_6.5.23_1min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\6-6.5.23\Houbi_PEPE_6.5.23_1min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Pepe\התמקדות של דקה\6-6.5.23\Binance_PEPE_6.5.23_1min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2023-05-06 06:50'
end_time = '2023-05-06 07:40'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]

# %% [markdown]
# 6.5.23 , PEPE , ALL exchanges prices

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='KuCoin', color='purple')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='blue')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='Binance', color='red')

plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=2))
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.FormatStrFormatter('%.8f'))  # For precise y-axis values

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('Pepe, 6.5.23 , Prices between the exchanges ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# SHIBA , 8.5.21 , OKX & Huobi

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\נתונים אינטרוול דקה\השקה Houbi&OKX\HOUBI_SHIB_8.5.21_1min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\נתונים אינטרוול דקה\השקה Houbi&OKX\OKX_SHIB_8.5.21_1min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2023-05-08 07:50'
end_time = '2023-05-08 08:40'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')

# Formatting
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=2))
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.FormatStrFormatter('%.8f'))  # For precise y-axis values
plt.xlabel('Time', fontsize=20)
plt.ylabel(' Price $', fontsize=20)
plt.title('SHIBA 8.5.21 ,OKX & Huobi,  1 min interval ', fontsize=25)
plt.xticks(rotation=45, fontsize=20)  # Font size for X-axis ticks
plt.yticks(fontsize=20)  # Font size for Y-axis ticks
plt.legend(fontsize=20)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# SHIBA , 10.5.21 , KuCoin Launch

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\נתונים אינטרוול דקה\השקה KuCoin&Binance\1\Huobi_SHIB_10.5.21_1min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\נתונים אינטרוול דקה\השקה KuCoin&Binance\1\OKX_SHIB_10.5.21_1min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\נתונים אינטרוול דקה\השקה KuCoin&Binance\1\KuCoin_SHIB_10.5.21_1min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\נתונים אינטרוול דקה\השקה KuCoin&Binance\1\Binance_SHIB_10.5.21_1min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2021-05-10 11:55'
end_time = '2021-05-10 13:55'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='KuCoin', color='purple')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='Binance', color='red')

plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=5))
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.FormatStrFormatter('%.8f'))  # For precise y-axis values

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('SHIBA , Prices between the exchanges ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# SHIBA, CoinBase Launch 16.9.21

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\נתונים אינטרוול דקה\CoinBase השקה\Huobi_SHIB_16.9.21_1min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\נתונים אינטרוול דקה\CoinBase השקה\OKX_SHIB_16.9.21_1min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\נתונים אינטרוול דקה\CoinBase השקה\KuCoin_SHIB_16.9.21_1min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\נתונים אינטרוול דקה\CoinBase השקה\Binance_SHIB_16.9.21_1min.csv')
df5 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\shiba\נתונים אינטרוול דקה\CoinBase השקה\CoinBase_SHIB_16.9.21_1min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)
df5['timestamp'] = pd.to_datetime(df5['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2021-09-16 17:00'
end_time = '2021-09-16 19:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]
filtered_df5 = df5[(df5['timestamp'] >= start_time) & (df5['timestamp'] <= end_time)]

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='KuCoin', color='purple')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='Binance', color='red')
plt.plot(filtered_df5['timestamp'], filtered_df5['open'], label='CoinBase', color='orange')

plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=4))
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.FormatStrFormatter('%.8f'))  # For precise y-axis values

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('SHIBA , Prices between the exchanges ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Tezos XTZ Launch on CoinBase 5.8.19

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\1Min_Interval_Data\CoinBase Launch 5.8.19\CoinBase_Tezos_5.8.19_1min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\1Min_Interval_Data\CoinBase Launch 5.8.19\KuCoin_Tezos_5.8.19_1min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2019-08-06 20:00'
end_time = '2019-08-06 22:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='CoinBase', color='orange')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='KuCoin', color='purple')


plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=4))
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.FormatStrFormatter('%.2f'))  # For precise y-axis values

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('Tezos (XTZ) , Prices between the exchanges ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Tezos Launch Huobi 8.8.19

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\1Min_Interval_Data\Huobi Launch 8.8.19\CoinBase_Tezos_8.8.19_1min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\1Min_Interval_Data\Huobi Launch 8.8.19\KuCoin_Tezos_8.8.19_1min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\1Min_Interval_Data\Huobi Launch 8.8.19\Huobi_Tezos_8.8.19_1min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2019-08-08 19:00'
end_time = '2019-08-08 21:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='CoinBase', color='orange')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='KuCoin', color='purple')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='blue')


plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=4))
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.FormatStrFormatter('%.2f'))  # For precise y-axis values

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('Tezos (XTZ) , Prices between the exchanges ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Tezos Launch on Binance 24.9.19

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\1Min_Interval_Data\Binance Launch 24.9.19\CoinBase_Tezos_24.9.19_1min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\1Min_Interval_Data\Binance Launch 24.9.19\KuCoin_Tezos_24.9.19_1min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\1Min_Interval_Data\Binance Launch 24.9.19\Huobi_Tezos_24.9.19_1min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\1Min_Interval_Data\Binance Launch 24.9.19\Binance_Tezos_24.9.19_1min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2019-09-24 19:00'
end_time = '2019-09-24 21:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='CoinBase', color='orange')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='KuCoin', color='purple')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='blue')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='Binance', color='red')


plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=4))
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.FormatStrFormatter('%.2f'))  # For precise y-axis values

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('Tezos (XTZ) , Prices between the exchanges ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Tezos OKX Launch 7.11.19

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\1Min_Interval_Data\OKX Launch 7.11.19\CoinBase_Tezos_7.11.19_1min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\1Min_Interval_Data\OKX Launch 7.11.19\KuCoin_Tezos_7.11.19_1min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\1Min_Interval_Data\OKX Launch 7.11.19\Huobi_Tezos_7.11.19_1min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\1Min_Interval_Data\OKX Launch 7.11.19\Binance_Tezos_7.11.19_1min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2019-11-07 01:00'
end_time = '2019-11-07 03:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='CoinBase', color='orange')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='KuCoin', color='purple')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='blue')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='Binance', color='red')


plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=4))
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.FormatStrFormatter('%.2f'))  # For precise y-axis values

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('Tezos (XTZ) , Prices between the exchanges ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Audio Launch on Huobi 25.2.22

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Audio\1Min\Data\Audio Launch Huobi 25.2.22\Binance_Audio_25.2.22_1min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Audio\1Min\Data\Audio Launch Huobi 25.2.22\KuCoin_Audio_25.2.22_1min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Audio\1Min\Data\Audio Launch Huobi 25.2.22\Huobi_Audio_25.2.22_1min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2022-02-25 11:30'
end_time = '2022-02-25 12:30'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Binance', color='red')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='KuCoin', color='purple')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='blue')


plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=2))
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.FormatStrFormatter('%.2f'))  # For precise y-axis values

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('Audio , Prices between the exchanges ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ATOM KuCoin Launch 24.5.19

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\1Min\Data\KuCoin_ATOM_24.5.19_1min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\1Min\Data\OKX_ATOM_24.5.19_1min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2019-05-24 19:40'
end_time = '2019-05-24 21:10'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='KuCoin', color='purple')


plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=2))
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.FormatStrFormatter('%.2f'))  # For precise y-axis values

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('ATOM , Prices between the exchanges ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()
