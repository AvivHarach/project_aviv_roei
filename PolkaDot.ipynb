# %% [markdown]
# Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Specify the correct date format
date_format = '%d/%m/%Y %H:%M'

# %% [markdown]
# Uploading Csv files & Filtering for first Launch on OKX 22.8.20

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\OKX_DOT_22-24.8.20_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\Binance_DOT_18-25.8.20_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\Huobi_DOT_22-24.8.20_5min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\KuCoin_DOT_21.8.20_5min.csv')
df5 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\CoinBase_DOT_16-18.6.21_5min.csv')
df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)
df5['timestamp'] = pd.to_datetime(df5['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2020-08-22 10:00'
end_time = '2020-08-22 18:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]
filtered_df5 = df5[(df5['timestamp'] >= start_time) & (df5['timestamp'] <= end_time)]

# %% [markdown]
# Uploading Csv files & Filtering for KuCoin Launch on 12.10.20

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\OKX_DOT_12-15.10.20_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\Binance_DOT_12-15.10.2020_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\Huobi_DOT_12-14.10.2020_5min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\KuCoin_DOT_11-15.10.20_5min.csv')
df5 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\CoinBase_DOT_16-18.6.21_5min.csv')
df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)
df5['timestamp'] = pd.to_datetime(df5['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2020-10-13 16:00'
end_time = '2020-10-14 00:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]
filtered_df5 = df5[(df5['timestamp'] >= start_time) & (df5['timestamp'] <= end_time)]

# %% [markdown]
# Uploading Csv files & Filtering for CoinBase Launch on 16.6.21

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\OKX_DOT_14-18.6.21_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\Binance_DOT_14-18.6.21_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\Huobi_DOT_14-18.6.21_5min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\KuCoin_DOT_16-21.6.21_5min.csv')
df5 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\CoinBase_DOT_16-18.6.21_5min.csv')
df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)
df5['timestamp'] = pd.to_datetime(df5['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2021-06-18 00:00'
end_time = '2021-06-18 08:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]
filtered_df5 = df5[(df5['timestamp'] >= start_time) & (df5['timestamp'] <= end_time)]

# %% [markdown]
# First Exchange Launch Plot

# %%
# Plot filtered data
plt.figure(figsize=(15, 9))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='OKX', color='blue')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))

plt.xlabel('Time ',fontsize=15)
plt.ylabel('Price $',fontsize=15)
plt.title('PolkaDot Launch on OKX 22.8.20',fontsize=30)
plt.xticks(rotation=45,fontsize=15)
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# First Exchange Launch Plot _2

# %%
# Plot filtered data
plt.figure(figsize=(15, 9))
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='Binance', color='blue')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))

plt.xlabel('Time ' ,fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('PolkaDot Launch on Binance 18.8.20', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Second Exchange Launch, OKX.

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='OKX', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='Binance', color='green')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=120))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('PolkaDot Launch on OKX, Lined with Binance ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %%
# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='Binance', color='green')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=240))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('PolkaDot Launch on OKX, Lined with Binance ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Third Coin Launch. plot of the first 3 coins's prices

# %%
# Plot three coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='OKX', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='Binance', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='red')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('PolkaDot Launch on OKX, Lined with Binance & Huobi ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Data Upload for KuCoin's Launch

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\OKX_DOT_22-24.8.20_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\Binance_DOT_18-25.8.20_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\Huobi_DOT_22-24.8.20_5min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\KuCoin_DOT_21.8.20_5min.csv')
df5 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\PolkaDot\CoinBase_DOT_16-18.6.21_5min.csv')
df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)
df5['timestamp'] = pd.to_datetime(df5['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2020-08-23 00:00'
end_time = '2020-08-23 08:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]
filtered_df5 = df5[(df5['timestamp'] >= start_time) & (df5['timestamp'] <= end_time)]

# %% [markdown]
# Forth Coin Launch. plot of the first 4 coins's prices

# %%
# Plot three coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='OKX', color='green')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='Binance', color='red')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='blue')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='KuCoin', color='purple')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.3f'))

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('PolkaDot Launch on KuCoin, Lined with OKX, Binance & Huobi ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Fifth Coin Launch. plot of all coins's prices

# %%
# Plot three coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='OKX', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='Binance', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='red')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='KuCoin', color='purple')
plt.plot(filtered_df5['timestamp'], filtered_df5['open'], label='CoinBase', color='orange')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))

plt.xlabel('Time', fontsize=15)
plt.ylabel(' Price $', fontsize=15)
plt.title('PolkaDot Launch on CoinBase, Lined with OKX, Binance , Huobi & KuCoin ', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()
