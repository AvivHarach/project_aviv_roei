# %% [markdown]
# Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Specify the correct date format
date_format = '%d/%m/%Y %H:%M'

# %% [markdown]
# Uploading Csv files & Filtering for KuCoin Launch on 28.6.19

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\KuCoin_XTZ_28.6.19-2.7.19_5min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2019-06-29 16:00'
end_time = '2019-06-30 00:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]

# %% [markdown]
# Uploading Csv files & Filtering for CoinBase Launch on 5.8.19

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\KuCoin_XTZ_5-13.8.19_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\CoinBase_XTZ_6-10.8.19_5min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2019-08-06 16:00'
end_time = '2019-08-07 00:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]

# %% [markdown]
# Uploading Csv files & Filtering for Huobi Launch on 8.8.19

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\KuCoin_XTZ_5-13.8.19_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\CoinBase_XTZ_6-10.8.19_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\Houbi_XTZ_8-9.8.2019_5min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2019-08-08 16:00'
end_time = '2019-08-08 21:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]

# %% [markdown]
# Uploading Csv files & Filtering for Binance Launch on 24.9.19

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\KuCoin_XTZ_24-28.9.19_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\CoinBase_XTZ_24-27.9.19_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\Huobi_XTZ_24-25.9.19_5min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\Binance_XTZ_24-25.09.19_5min.csv')
df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2019-09-24 08:00'
end_time = '2019-09-24 16:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]

# %% [markdown]
# Uploading Csv files & Filtering for OKX Launch on 7.11.19

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\KuCoin_XTZ_6-10.11.19_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\CoinBase_XTZ_7-9.11.19_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\Huobi_XTZ_6-8.11.19_5min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\Binance_XTZ_6-10.11.19_5min.csv')
df5 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Tezos (XTZ)\OKX_XTZ_7-8.11.2019_5min.csv')
df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)
df5['timestamp'] = pd.to_datetime(df5['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2019-11-07 00:00'
end_time = '2019-11-07 08:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]
filtered_df5 = df5[(df5['timestamp'] >= start_time) & (df5['timestamp'] <= end_time)]

# %% [markdown]
# Tezos Launch on KuCoin, 28.6.19

# %%
# Plot filtered data
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='KuCoin', color='blue')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))
plt.xlabel('Time ',fontsize=15)
plt.ylabel('Price $',fontsize=15)
plt.title('Tezos Launch on KuCoin 28.6.19',fontsize=30)
plt.xticks(rotation=45,fontsize=15)
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Tezos Launch on CoinBase, 5.8.19

# %%
# Plot filtered data
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='KuCoin', color='purple')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='CoinBase', color='orange')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))
plt.xlabel('Time ',fontsize=15)
plt.ylabel('Price $',fontsize=15)
plt.title('Tezos Launch on CoinBase, 6.8.19',fontsize=30)
plt.xticks(rotation=45,fontsize=15)
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Tezos Launch on Huobi, 8.8.19

# %%
# Plot filtered data
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='KuCoin', color='purple')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='CoinBase', color='orange')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='blue')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))
plt.xlabel('Time ',fontsize=15)
plt.ylabel('Price $',fontsize=15)
plt.title('Tezos Launch on Huobi, 8.8.19',fontsize=30)
plt.xticks(rotation=45,fontsize=15)
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Tezos Launch on Binance, 24.9.19

# %%
# Plot filtered data
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='KuCoin', color='purple')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='CoinBase', color='orange')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='blue')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='Binance', color='red')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))
plt.xlabel('Time ',fontsize=15)
plt.ylabel('Price $',fontsize=15)
plt.title('Tezos Launch on OKX, 7.11.19',fontsize=30)
plt.xticks(rotation=45,fontsize=15)
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Tezos Launch on OKX, 7.11.19

# %%
# Plot filtered data
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='KuCoin', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='CoinBase', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='red')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='Binance', color='purple')
plt.plot(filtered_df5['timestamp'], filtered_df5['open'], label='OKX', color='orange')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))
plt.xlabel('Time ',fontsize=15)
plt.ylabel('Price $',fontsize=15)
plt.title('Tezos Launch on OKX, 7.11.19 ',fontsize=30)
plt.xticks(rotation=45,fontsize=15)
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()
