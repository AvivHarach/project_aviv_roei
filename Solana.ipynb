# %% [markdown]
# Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Specify the correct date format
date_format = '%d/%m/%Y %H:%M'

# %% [markdown]
# Uploading Csv files & Filtering for Binance Launch on 9.4.20 - NO DATA FOR THIS DATE

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\Binance_SOL_11-12.8.20_5min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2020-04-09 08:00'
end_time = '2020-04-09 16:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]

# %% [markdown]
# Uploading Csv files & Filtering for OKX Launch 29.9.20 - DATA STARTS FROM 30.9.20

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\Binance_SOL_29.9.20-2.10.20_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\OKX_SOL_30.9.20-1.10.20_5min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2020-10-01 16:00'
end_time = '2020-10-02 00:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]

# %% [markdown]
# Uploading Csv files & Filtering for Huobi Launch on 3.12.20

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\Binance_SOL_3-5.12.20_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\OKX_SOL_3-5.12.20_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\Huobi_SOL_3-5.12.20_5min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2020-12-04 16:00'
end_time = '2020-12-05 00:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]

# %% [markdown]
# Uploading Csv files & Filtering for CoinBase Launch on 17.6.21

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\Binance_SOL_16-18.6.21_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\OKX_SOL_16-18.6.21_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\Huobi_SOL_16-18.6.21_5min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\CoinBase_SOL_17-18.6.21_5min.csv')
df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2021-06-18 16:00'
end_time = '2021-06-19 00:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]

# %% [markdown]
# Uploading Csv files & Filtering for KuCoin Launch on 4.8.21

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\Binance_SOL_4-6.8.21_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\OKX_SOL_4-6.8.21_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\Huobi_SOL_4-6.8.21_5min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\KuCoin_SOL_4-8.8.21_5min.csv')
df5 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\Solana(SOL)\CoinBase_SOL_4-6.8.21_5min.csv')
df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)
df5['timestamp'] = pd.to_datetime(df5['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2021-08-05 16:00'
end_time = '2021-08-06 00:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]
filtered_df5 = df5[(df5['timestamp'] >= start_time) & (df5['timestamp'] <= end_time)]

# %% [markdown]
# Solana Launch on OKX 29.9.20 - Data for OKX starts from 30.9

# %%
# Plot filtered data
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Binance', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))
plt.xlabel('Time ',fontsize=15)
plt.ylabel('Price $',fontsize=15)
plt.title('Solana Launch on OKX, Lined with Binance 29.9.20',fontsize=30)
plt.xticks(rotation=45,fontsize=15)
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Solana Launch on Huobi, Lined with OKX & Binance 3.12.20

# %%
# Plot filtered data
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Binance', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='red')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))
plt.xlabel('Time ',fontsize=15)
plt.ylabel('Price $',fontsize=15)
plt.title('Solana Launch on Huobi, Lined with Binance & OKX 3.12.20',fontsize=30)
plt.xticks(rotation=45,fontsize=15)
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Solana Launch on CoinBase, Lined with OKX & Binance & Huobi 17.6.21

# %%
# Plot filtered data
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Binance', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='red')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='CoinBase', color='purple')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))
plt.xlabel('Time ',fontsize=15)
plt.ylabel('Price $',fontsize=15)
plt.title('Solana Launch on CoinBase, Lined with Binance & OKX & Huobi 17.6.21',fontsize=30)
plt.xticks(rotation=45,fontsize=15)
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# Solana Launch on KuCoin, Lined with all 4.8.21

# %%
# Plot filtered data
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Binance', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Huobi', color='red')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='CoinBase', color='purple')
plt.plot(filtered_df5['timestamp'], filtered_df5['open'], label='KuCoin', color='orange')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.8f'))
plt.xlabel('Time ',fontsize=15)
plt.ylabel('Price $',fontsize=15)
plt.title('Solana Launch on KuCoin, Lined with all 4.8.21',fontsize=30)
plt.xticks(rotation=45,fontsize=15)
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()
