# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Specify the correct date format
date_format = '%d/%m/%Y %H:%M'

# %% [markdown]
# ATOM Launch on HTX & OKX 23.4.19

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\Data\Huobi_COSMOS_23.4.19_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\Data\OKX_COSMOS_23.4.19_5min.csv')
df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2019-04-24 08:00'
end_time = '2019-04-24 16:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))

plt.xlabel('Time', fontsize=15)
plt.ylabel('Price $', fontsize=15)
plt.title('ATOM Launch on OKX & Huobi', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ATOM Launch on Binance 29.4.19

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\Data\Huobi_COSMOS_29.4.19_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\Data\OKX_COSMOS_29.4.19_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\Data\Binance_ATOM_29.4.19_5min.csv')
df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)

# Define the filter date range
start_time = '2019-04-30 08:00'
end_time = '2019-04-30 16:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Binance', color='red')

plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))

plt.xlabel('Time', fontsize=15)
plt.ylabel('Price $', fontsize=15)
plt.title('ATOM Launch on Binance', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ATOM Launch on KuCoin 24.5.19

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\Data\Huobi_ATOM_22.5.19_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\Data\OKX_COSMOS_22.5.19_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\Data\Binance_ATOM_23.5.19_5min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\Data\KuCoin_ATOM_24.5.19_5min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2019-05-25 00:00'
end_time = '2019-05-25 08:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Binance', color='red')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='KuCoin', color='purple')

plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))

plt.xlabel('Time', fontsize=15)
plt.ylabel('Price $', fontsize=15)
plt.title('ATOM Launch on KuCoin', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ATOM Launch on CoinBase 14.2.20

# %%
df1 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\Data\Huobi_COSMOS_14.2.20_5min.csv')
df2 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\Data\OKX_COSMOS_14.2.20_5min.csv')
df3 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\Data\Binance_ATOM_14.2.20_5min.csv')
df4 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\Data\KuCoin_ATOM_14.2.20_5min.csv')
df5 = pd.read_csv(r'C:\Users\avivh\Desktop\פרוייקט גמר\Data\ATOM\Data\CoinBase_ATOM_14.2.20_5min.csv')

df1['timestamp'] = pd.to_datetime(df1['timestamp'], format=date_format, dayfirst=True)
df2['timestamp'] = pd.to_datetime(df2['timestamp'], format=date_format, dayfirst=True)
df3['timestamp'] = pd.to_datetime(df3['timestamp'], format=date_format, dayfirst=True)
df4['timestamp'] = pd.to_datetime(df4['timestamp'], format=date_format, dayfirst=True)
df5['timestamp'] = pd.to_datetime(df5['timestamp'], format=date_format, dayfirst=True)


# Define the filter date range
start_time = '2020-02-15 00:00'
end_time = '2020-02-15 08:00'

filtered_df1 = df1[(df1['timestamp'] >= start_time) & (df1['timestamp'] <= end_time)]
filtered_df2 = df2[(df2['timestamp'] >= start_time) & (df2['timestamp'] <= end_time)]
filtered_df3 = df3[(df3['timestamp'] >= start_time) & (df3['timestamp'] <= end_time)]
filtered_df4 = df4[(df4['timestamp'] >= start_time) & (df4['timestamp'] <= end_time)]
filtered_df5 = df5[(df5['timestamp'] >= start_time) & (df5['timestamp'] <= end_time)]

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Plot both coins together
plt.figure(figsize=(25, 15))
plt.plot(filtered_df1['timestamp'], filtered_df1['open'], label='Huobi', color='blue')
plt.plot(filtered_df2['timestamp'], filtered_df2['open'], label='OKX', color='green')
plt.plot(filtered_df3['timestamp'], filtered_df3['open'], label='Binance', color='red')
plt.plot(filtered_df4['timestamp'], filtered_df4['open'], label='KuCoin', color='purple')
plt.plot(filtered_df5['timestamp'], filtered_df5['open'], label='CoinBase', color='orange')

plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d/%m %H:%M'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MinuteLocator(interval=30))

# Format y-axis to avoid rounding
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))

plt.xlabel('Time', fontsize=15)
plt.ylabel('Price $', fontsize=15)
plt.title('ATOM Launch on CoinBase', fontsize=15)
plt.xticks(rotation=45, fontsize=15)  # Font size for X-axis ticks
plt.yticks(fontsize=15)  # Font size for Y-axis ticks
plt.legend(fontsize=15)  # Font size for the legend
plt.tight_layout()
plt.show()
